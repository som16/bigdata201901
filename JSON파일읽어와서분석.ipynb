# %%
import pandas as pd

# %%
df = pd.read_json("C:/Users/PC/Documents/DataScience/data/gangnam2.json")

# %%
print(df.count())
# Out:
# bloggerlink    2000
# bloggername    2000
# description    2000
# link           2000
# postdate       2000
# title          2000
# dtype: int64

# %%
df
# Out:
#                                 bloggerlink  \
# 0             http://blog.naver.com/talk442
# 1         http://blog.naver.com/kwoncharm_e
# 2             http://blog.naver.com/llillo2
# 3        http://blog.naver.com/powersub1101
# 4          http://blog.naver.com/hongik9016
# 5          http://blog.naver.com/kooltz1018
# 6         http://blog.naver.com/mihee850925
# 7            http://blog.naver.com/takuteru
# 8           http://blog.naver.com/greenjbee
# 9           http://blog.naver.com/sodam3826
# 10          http://blog.naver.com/yoon_shye
# 11        http://blog.naver.com/jisunny1215
# 12           http://blog.naver.com/iamdolza
# 13            http://blog.naver.com/talk442
# 14            http://blog.naver.com/roynmin
# 15            http://blog.naver.com/nhj9943
# 16             http://blog.naver.com/gyrudp
# 17            http://blog.naver.com/nanumi_
# 18             http://blog.naver.com/0122kj
# 19              http://blog.naver.com/eusia
# ...

# %%
df_sum = df.groupby("bloggername").count()
df_sum
# Out:
#                                   bloggerlink  description  link  postdate  \
# bloggername
# "日本満喫‼"블러그                                  1            1     1         1
# "언제나 감사하며 살자"                               1            1     1         1
# "해강+재곰=해곰이"                                 1            1     1         1
# #                                           1            1     1         1
# # 나의 작은 작업실                                 1            1     1         1
# (♡˙︶˙♡)                                     1            1     1         1
# * VATERIUM *                                2            2     2         2
# * memories *                                1            1     1         1
# * 고밍과 드브, 의식의 공간 *                          1            1     1         1
# * 봉추미의 일상                                   1            1     1         1
# * 행복의 프리즘 *                                 1            1     1         1
# ...

# %%
# visual studio로 .json파일 열어서 코드를 JSON.Viewer로 보기

# %%
df['bloggername']
# Out:
# 0                                 비키의 소소한일상:)
# 1                           권매력의 charming-DAY
# 2                                     우기부기블로그
# 3                                       귀찮은 섭
# 4                             아가리파이터의 한.술.담.끼
# 5           Ever thine, Ever mine, Ever ours.
# 6                                    날마다 좋은 날
# 7                    Let's Go Fashion World~♡
# 8                             자신의 자리에서 빛나는 사람
# 9                                  기억, 추억, 생각
# 10                                  그녀가 사는 세상
# 11                            룰루랄라, favorance
# 12                           DOLZA'S EAT&JOY!
# 13                                비키의 소소한일상:)
# 14                                      로민유랑단
# 15                                     막돼먹은찌니
# 16                                   orizzang
# 17                               나누미의 유쾌한 나눔통
# 18                               찌주의 데일리블로그 ♡
# 19                                     인생은 짧다
# ...

# %%
df['title']
# Out:
# 0                               <b>강남역 맛집</b> 여자들이 좋아할만해!
# 1                                   <b>강남역 맛집</b> 숨어있는 핫플
# 2                            <b>강남역 맛집</b> 매운갈비찜의 정석 신맵당!
# 3                                 <b>강남역 맛집</b> 색다른 나폴리회관
# 4                                 <b>강남역 맛집</b> 진한 여운이 남다
# 5                                   <b>강남역 맛집</b> 색다른 도전~
# 6                                    <b>강남역 맛집</b> 가야만하오!
# 7                                 <b>강남역 맛집</b> 후회 없는 이곳!
# 8                                 <b>강남역 맛집</b> 분위기로 여심저격
# 9                         <b>강남역 맛집</b> 이딸라시안 여길 왜 이제갔지!?
# 10                            <b>강남역 맛집</b> 바비레드 꼭가기 두번가기
# 11                                   <b>강남역 맛집</b> 고급진 그곳
# 12                                  <b>강남역 맛집</b> 일식을 느끼다
# 13                             <b>강남역 맛집</b> 요건 못 먹어 봤을껄?
# 14                          <b>강남역 맛집</b> :: 또 먹고 싶어지는 곳!
# 15                             <b>강남역 맛집</b> 매콤한맛 하면 여기지!
# ...

# %%
blogname = pd.DataFrame.from_dict(df['bloggername'])

# %%
blogname
# Out:
#                                 bloggername
# 0                               비키의 소소한일상:)
# 1                         권매력의 charming-DAY
# 2                                   우기부기블로그
# 3                                     귀찮은 섭
# 4                           아가리파이터의 한.술.담.끼
# 5         Ever thine, Ever mine, Ever ours.
# 6                                  날마다 좋은 날
# 7                  Let's Go Fashion World~♡
# 8                           자신의 자리에서 빛나는 사람
# 9                                기억, 추억, 생각
# 10                                그녀가 사는 세상
# 11                          룰루랄라, favorance
# 12                         DOLZA'S EAT&JOY!
# 13                              비키의 소소한일상:)
# 14                                    로민유랑단
# 15                                   막돼먹은찌니
# 16                                 orizzang
# 17                             나누미의 유쾌한 나눔통
# 18                             찌주의 데일리블로그 ♡
# 19                                   인생은 짧다
# ...

# %%
blog = pd.DataFrame.from_dict(df.loc[:, ['bloggername', 'title', 'description', 'postdate']])

# %%
# .json은 대부분의 프로그램들이 선호하는 데이터 타입 : 가장 많이 사용.
# .csv 형식으로 저장
blog.to_csv('../data/gangnam.csv', encoding='UTF-8')

# %%
read_csv = pd.read_csv('../data/gangnam.csv')
read_csv
# Out:
#       Unnamed: 0                            bloggername  \
# 0              0                            비키의 소소한일상:)
# 1              1                      권매력의 charming-DAY
# 2              2                                우기부기블로그
# 3              3                                  귀찮은 섭
# 4              4                        아가리파이터의 한.술.담.끼
# 5              5      Ever thine, Ever mine, Ever ours.
# 6              6                               날마다 좋은 날
# 7              7               Let's Go Fashion World~♡
# 8              8                        자신의 자리에서 빛나는 사람
# 9              9                             기억, 추억, 생각
# 10            10                              그녀가 사는 세상
# 11            11                        룰루랄라, favorance
# 12            12                       DOLZA'S EAT&JOY!
# 13            13                            비키의 소소한일상:)
# 14            14                                  로민유랑단
# 15            15                                 막돼먹은찌니
# ...

# %%
read_csv.sort_values(by = 'bloggername', ascending = False).head(10)
# Out:
#       Unnamed: 0                       bloggername  \
# 891          891                    ＊문화스토커 위트의 다락방
# 525          525                         힘과 꾸망이 가득
# 1172        1172                                히얏
# 1541        1541                              히뽀후드
# 1186        1186                           희짱월드:♥)
# 1107        1107                         희블리의 행복찾기
# 156          156                         흥청망청 후이로그
# 1470        1470                           흐름을 넘어서
# 801          801  흐르는 강물처럼(Like the flowing river)
# 1577        1577                 회색도시의 TV...그리고 여행
#
#                                              title  \
# 891        <b>강남역 맛집</b> 파파야리프에서 맛있는 태국음식!:) 강남 맛집
# 525                    <b>강남역 맛집</b> 난 욕심 많게 싸먹을거당
# 1172                       <b>강남역</b> 카페래이 떡와플 와우~
# 1541                              외국인과 함께한 인사동 나들이
# 1186         <b>강남</b><b>찻집</b>@ CHLORIS TEA ROOMS
# 1107           [<b>강남역</b> 카페/ 분위기 좋은 디저트 카페] 마망갸또
# ...

# %%
#1. postdate로 정렬
#2. postdate로 그룹지어 count
#3. 블로거네임으로 일차정렬, postdate로 2차 정렬
#4. 3번의 결과를 count
#5. 4번의 결과를 title로 내림차순

# %%
# 1.
read_csv.sort_values(by = 'postdate', ascending = False).head(10)
# Out:
#      Unnamed: 0        bloggername  \
# 22           22  GRACE's lov diary
# 875         875          러브잇 LUVIT
# 870         870         허니크리아 블로그♡
# 69           69       Only on date
# 44           44         라미의 멀티 뮤지엄
# 475         475      즐기자, Rah Kim!
# 21           21            내.몸.사.랑
# 579         579       먹방강자의 소소한 일상
# 728         728        새콤이의 블로그♥.♥
# 787         787                럽로그
#
#                                                  title  \
# 22   <b>강남역 맛집</b> + 카페 데이트, 핫한 곱창쌀국수 &quot;땀땀&quot...
# 875                    <b>강남역맛집</b>]분위기도 좋고 넘 맛있는 낙원타코
# 870                        [<b>강남역 맛집</b>] 대왕 치즈 본토닭갈비
# 69                 <b>강남역 맛집</b> - 스테이크와 라멘의 조화 도쿄스테이크
# 44       [<b>강남역 맛집</b>] 장인닭갈비... 인생 맛집. 저는 강남역 가면...
# 475   [<b>강남역 맛집</b>/강남역 혼밥] 직화한상 '정직한 한끼' - 평점 3.73/5
# 21                      <b>강남역 맛집</b> 베스트10 퇴근하고 힐링타임!
# 579                           <b>강남역맛집</b> :: 무교동 유정낙지
# 728                   <b>강남역맛집</b> 베스트10 , 당연히 메이드바이오즈
# ...

# %%
# 2. 
df_date_sum = df.groupby("postdate").count()
df_date_sum
# Out:
#           bloggerlink  bloggername  description  link  title
# postdate
#                     1            1            1     1      1
# 20030421            1            1            1     1      1
# 20030725            1            1            1     1      1
# 20031014            1            1            1     1      1
# 20031210            1            1            1     1      1
# 20040516            1            1            1     1      1
# 20040522            1            1            1     1      1
# 20040616            1            1            1     1      1
# 20040725            1            1            1     1      1
# 20040801            1            1            1     1      1
# 20040920            1            1            1     1      1
# 20041023            1            1            1     1      1
# 20041024            2            2            2     2      2
# 20041123            1            1            1     1      1
# ...

# %%
# 3.
#3. 블로거네임으로 일차정렬, postdate로 2차 정렬
#4. 3번의 결과를 count
#5. 4번의 결과를 title로 내림차순
df_sort = read_csv.sort_values(by = 'bloggername', ascending = True)
df_sort
df_sort = df_sort.sort_values(by = 'postdate', ascending = False)
df_sort
# Out:
#       Unnamed: 0                     bloggername  \
# 44            44                      라미의 멀티 뮤지엄
# 870          870                      허니크리아 블로그♡
# 22            22               GRACE's lov diary
# 69            69                    Only on date
# 875          875                       러브잇 LUVIT
# 475          475                   즐기자, Rah Kim!
# 579          579                    먹방강자의 소소한 일상
# 21            21                         내.몸.사.랑
# 0              0                     비키의 소소한일상:)
# 728          728                     새콤이의 블로그♥.♥
# 4              4                 아가리파이터의 한.술.담.끼
# 787          787                             럽로그
# 167          167                           즐겁게살자
# 82            82                           맵씨블로그
# 62            62                    지극히 주관적인 블로그
# 27            27                          맛집깡패~♥
# 735          735                         m_diary
# 358          358                               ♪
# ...
