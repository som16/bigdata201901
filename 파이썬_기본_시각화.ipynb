# %% [markdown]
# <a href="https://colab.research.google.com/github/som16/bigdata201901/blob/master/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EB%B3%B8_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.figure() # 그래프의 사각형
plt.plot([1,2,1,5,1,1,2,3,5,4,2,1,3,3,5,4])
plt.show() # 그래프 보여주기

# %%
import numpy as np # 통계와 관련된 예제

# %%
t = np.arange(0, 12, 0.01)

# %%
y = np.sin(t)
z = np.cos(t)

# %%
# 그래프를 그리는 기본 함수 세트
# plt.figure() : 시작
# plt.plot()
# pli.show() : 끝

# %%
plt.figure(figsize = (10, 6))
plt.plot(t, y, label = 'sin', lw = 5)
plt.plot(t, z,'g^', label = 'cos') # 그래프를 추가하고 싶을 때 : np.plot() 추가
# 'g^' 점모양 변경
# 알파벳 : 색깔
# ^ : 산모양
# -- : 점선
# s : 네모
# plt.plot(t, y, label = 'sin', lw = 5, color = 'red', linestyle = 'dashed', marker='o')  : 세부조정 예시
plt.legend() # 범례추가
plt.grid() # 격자 제거
plt.xlabel('time')
plt.ylabel('value')
plt.title('my graph')
pli.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e914e4855d09> in <module>()
#      13 plt.ylabel('value')
#      14 plt.title('my graph')
# ---> 15 pli.show()
#
# NameError: name 'pli' is not defined

# %%
t2 = np.arange(0, 5, 0.5)

# %%
plt.figure(figsize=(10,6))

# %%
plt.plot(t2, t2, 'r--')
plt.plot(t2, t2*2, 'bs')
plt.plot(t2, t2*3, 'g^')
plt.plot(t2, t2*4, color = 'pink', linestyle = 'dashed', marker='o')
plt.xlabel('가로축')
plt.ylabel('세로축')
plt.title('제목')
plt.show()

# %%
s1 = np.random.normal(loc = 0, scale = 1, size = 1000)
s2 = np.random.normal(loc = 5, scale = 0.5, size = 1000)
s3 = np.random.normal(loc = 10, scale = 1.2, size = 1000)

# %%
plt.figure(figsize = (10, 6))
plt.plot(s1, label = 's1')
plt.plot(s2, label = 's2')
plt.plot(s3, label = 's3')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.boxplot((s1, s2, s3))
plt.show()

# %%
# 파이썬 파일로 다운로드 받기 : 파일 > .py 다운로드
